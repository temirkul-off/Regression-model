# %%
# %run "03. EDA.ipynb"
# Out:
# Number of removed outliers: 1342
# Number of removed outliers: 555

# %%
testset = preprocess_test(test_main_df, test_additional_df)

# %%
testset.isna().sum()
# Out:
# id                                   0
# timestamp                            0
# full_sq                              0
# life_sq                              0
# floor                                0
# max_floor                            0
# material                             0
# build_year                           0
# num_room                             0
# kitch_sq                             0
# apartment_condition                  0
# sub_area                             0
# year                                 0
# population                           0
# indust_part                          0
# preschool_facilities                 0
# school_facilities                    0
# hospital_beds_raion                474
# healthcare_facilities                0
# university_num                       0
# sport_objects_facilities             0
# additional_education_facilities      0
# culture_objects_facilities           0
# shopping_centers_facilities          0
# ...
