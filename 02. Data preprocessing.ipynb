# %%
import pandas as pd
import numpy as np
from utils import *


pd.set_option('display.max_columns', 50)

# %run "01. Separating training and testing sets.ipynb"

# %%
valid_df.isna().sum()
# Out:
# id                        0
# timestamp                 0
# full_sq                   0
# life_sq                1955
# floor                     0
# max_floor                 0
# material                  0
# build_year             1786
# num_room                  0
# kitch_sq                  0
# apartment_condition    1338
# sub_area                  0
# price                     0
# dtype: int64

# %%
train = preprocess(train_df, train_additional_df)
valid = preprocess(valid_df,train_additional_df)

# %%
train.isna().sum()
# Out:
# id                                    0
# timestamp                             0
# full_sq                               0
# life_sq                               0
# floor                                 0
# max_floor                          9119
# material                              0
# build_year                            0
# num_room                              0
# kitch_sq                              0
# apartment_condition                   0
# sub_area                              0
# price                                 0
# year                                  0
# population                            0
# indust_part                           0
# preschool_facilities                  0
# school_facilities                     0
# hospital_beds_raion                9370
# healthcare_facilities                 0
# university_num                        0
# sport_objects_facilities              0
# additional_education_facilities       0
# ...

# %%
trset = feature_gen(train)
valset = feature_gen(valid)

# %%
trset
valset
# Out:
#          id  full_sq    life_sq  floor  max_floor  material  build_year  \
# 0     22460     36.0  16.000000    2.0       14.0       2.0        1995
# 1     59777    121.0  62.000000   19.0       23.0       4.0        2007
# 2     31922     47.0  29.000000    1.0       12.0       1.0        1981
# 3     70231     41.0  26.027585    5.0        1.0       1.0        1986
# 4     68508     39.0  20.000000   10.0       22.0       1.0        2000
# ...     ...      ...        ...    ...        ...       ...         ...
# 8694  90470     86.0  59.000000    3.0        9.0       2.0        1935
# 8695  27132     57.0  37.555183   13.0       17.0       1.0        1988
# 8696  39753     40.0  26.000000    3.0        9.0       2.0        1972
# 8697  17374     39.0  20.000000    7.0       12.0       1.0        1982
# 8698  79517     37.0  23.067834    3.0        3.0       1.0        1989
#
#       num_room  kitch_sq  apartment_condition  sub_area         price  year  \
# ...
